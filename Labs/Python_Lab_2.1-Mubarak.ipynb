# %% [markdown]
# # Python_Lab_2.1

# %% [markdown]
# ### Task 1
# 1. Write a function named is_prime that takes a number as a parameter and returns True if the number is prime and False otherwise. Print whether the number 29 is prime.

# %%
# write your code here ^_^
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5)+1):
        if n % i == 0:
            return False
    return True

print(is_prime(29))
# Out:
# True

# %% [markdown]
# ### Task 2
# 1. Create a list of 10 numbers and sort them in descending order using the sort() function.
# 2. Use the len() function to print the length of the sorted list.
# 3. Use the zip() function to combine three lists (names, ages, and cities) into a list of tuples.
# 4. Use the range() function to create a list of even numbers from 2 to 20 and print the list.

# %%
# write your code here ^_^
import random
lst1 = [random.randint(0, 100) for i in range(10)]
lst1.sort(reverse=True)
print(lst1)
print("length =",len(lst1))
# Out:
# [87, 86, 63, 62, 60, 52, 36, 34, 7, 4]
# length = 10

# %%
names = ["Ali", "Mubarak", "Saad", "Faisal", "Faris"]
ages = [19, 22, 25, 18, 27]
cities = ["Riyadh", "Jeddah", "Abha", "Dammam", "Mecca"]

print(list(zip(names, ages, cities)))
# Out:
# [('Ali', 19, 'Riyadh'), ('Mubarak', 22, 'Jeddah'), ('Saad', 25, 'Abha'), ('Faisal', 18, 'Dammam'), ('Faris', 27, 'Mecca')]

# %%
list1 =[i for i in range(2,20,2)]
print(list1)
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16, 18]

# %% [markdown]
# ### Task 3
# Build a phone book program that receives the phone number, and returns the name of the owner.
# You can follow the table below:
#
# | Name     | Number     |
# | -------- | ---------- |
# | Amal     | 1111111111 |
# | Mohammed | 2222222222 |
# | Khadijah | 3333333333 |
# | Abdullah | 4444444444 |
# | Rawan    | 5555555555 |
# | Faisal   | 6666666666 |
# | Layla    | 7777777777 |
#
# - If the number exists, print the owner. Otherwise, print "Sorry, the number is not found".
# - If the number is less or more than 10 numbers, print "This is invalid number".
# - If the number contains letters or symbols, print "This is invalid number".

# %%
# write your code here ^_^
dict = {1111111111: "Amal", 2222222222:"Mohammed", 3333333333:"Khadijah", 4444444444:"Abdullah", 5555555555:"Rawan", 6666666666:"Faisal", 7777777777:"Layla"}

def check_num(num):
    if len(str(num)) != 10:
        print("This is invalid number (not 10 digits)")
        return
    elif not isinstance(num, (int, float)):
        print("This is invalid number (contains non-numric value)")
        return
    elif num in dict:
        return dict[num]
    else:
        print("Sorry, the number is not found")
        return
    
check_num(9999999999)
# Out:
# Sorry, the number is not found

# %% [markdown]
# ### Task 4
# - Given the following list : [5, 4, 17, 19, 30, 2, 7, 10, 45]
#     1. Use a lambda function to filter out only the odd numbers.
#     2. Print the new list of odd numbers.

# %%
# write your code here ^_^
nums = [5, 4, 17, 19, 30, 2, 7, 10, 45]
odd_numbers = list(filter(lambda x: x%2==1, nums))
print(odd_numbers)
# Out:
# [5, 17, 19, 7, 45]
